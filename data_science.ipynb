# %% [markdown]
# # ライブラリインポート

# %%
import pandas as pd
from collections import Counter
import unicodedata
import string 
import emoji
import re

# %% [markdown]
# # データチェック

# %%
ls
# Out:
# README.md           ai_app/             data_science.ipynb  sample.csv

# %%
pwd
# Out:
# '/Users/aipon/Works/rakuma_NLP'

# %%
df = pd.read_csv("sample.csv", sep=",", engine="python")

# %%
df.head(10)
# Out:
#                                     title                     category
# 0                             カナヘイ ノートセット  おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 1        DX ワンダーライドブック 2種 セット 仮面ライダー セイバー  おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 2     田中くんはいつもけだるげまとめ売り クリアファイル アクキー 缶バッジ  おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 3                  ディズニーワールドのクロックスのアクセサリー  おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 4                           僕のヒーローアカデミア　轟  おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 5              ヒロアカヒーローズライジングアクリスタンド 蛙吹梅雨  おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 6          呪術廻戦 アクリルフィギュアコレクション 虎杖悠仁 両面宿儺  おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 7           ラウンドワン限定 サンリオ ポムポムプリン バニティポーチ  おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 8            第五人格　ぴた！でふぉめ　アクリルスタンド　庭師 納棺師  おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 9  マタニティ さるぼぼ マタニティマーク ストラップ　臨月 妊娠中 妊婦 妊娠  おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ

# %%
df.info
# Out:
# <bound method DataFrame.info of                                          title                      category
# 0                                  カナヘイ ノートセット   おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 1             DX ワンダーライドブック 2種 セット 仮面ライダー セイバー   おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 2          田中くんはいつもけだるげまとめ売り クリアファイル アクキー 缶バッジ   おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 3                       ディズニーワールドのクロックスのアクセサリー   おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 4                                僕のヒーローアカデミア　轟   おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# ...                                        ...                           ...
# 1457927                    定期入れ　カード入れ　小銭入れ　ピンク            レディース>小物>名刺入れ/定期入れ
# 1457928                             LOEWE マフラー            レディース>小物>マフラー/ショール
# 1457929                             ダーリッチ ストール            レディース>小物>ストール/スヌード
# 1457930  粘土道具 粘土ヘラ かきべら 6本セット クレイクラフト 陶芸 工芸 彫像        おもちゃ・ホビー・グッズ>アート用品>その他
# 1457931                           ジュース入れシャンデリア  自動車・オートバイ>自動車アクセサリー>車内アクセサリー
#
# ...

# %%
len(df)
# Out:
# 1457932

# %%
df.category.nunique()
# Out:
# 1161

# %%
ctg_df = df.category.value_counts().reset_index()

# %%
ctg_df
# Out:
#                                 category   count
# 0            おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ  113754
# 1              おもちゃ・ホビー・グッズ>タレントグッズ>アイドル   50977
# 2     おもちゃ・ホビー・グッズ>トレーディングカード>ポケモンカードゲーム   24256
# 3                  本・音楽・ゲーム>CD>K-POP/アジア   21494
# 4            おもちゃ・ホビー・グッズ>トレーディングカード>遊戯王   20234
# ...                                  ...     ...
# 1156            レディース>スーツ/フォーマル/ドレス>シューズ       1
# 1157       インテリア・住まい・小物>ベッド/マットレス>キングベッド       1
# 1158                      チケット>演劇/芸能>オペラ       1
# 1159         インテリア・住まい・小物>ベッド/マットレス>収納付き       1
# 1160                    チケット>スポーツ>バレーボール       1
#
# [1161 rows x 2 columns]

# %%
over1000_data = ctg_df[ctg_df["count"] > 1000]

# %%
over1000_data
# Out:
#                                category   count
# 0           おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ  113754
# 1             おもちゃ・ホビー・グッズ>タレントグッズ>アイドル   50977
# 2    おもちゃ・ホビー・グッズ>トレーディングカード>ポケモンカードゲーム   24256
# 3                 本・音楽・ゲーム>CD>K-POP/アジア   21494
# 4           おもちゃ・ホビー・グッズ>トレーディングカード>遊戯王   20234
# ..                                  ...     ...
# 307           おもちゃ・ホビー・グッズ>おもちゃ>ホビーラジコン    1017
# 308                   レディース>トップス>ベスト/ジレ    1015
# 309      おもちゃ・ホビー・グッズ>コミック/アニメグッズ>ストラップ    1015
# 310              チケット>優待券/割引券>レストラン/食事券    1005
# 311                  ベビー・キッズ>行事/記念品>その他    1001
#
# [312 rows x 2 columns]

# %%
over1000_data["count"].sum()
# Out:
# 1218297

# %%
df
# Out:
#                                          title                      category
# 0                                  カナヘイ ノートセット   おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 1             DX ワンダーライドブック 2種 セット 仮面ライダー セイバー   おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 2          田中くんはいつもけだるげまとめ売り クリアファイル アクキー 缶バッジ   おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 3                       ディズニーワールドのクロックスのアクセサリー   おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 4                                僕のヒーローアカデミア　轟   おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# ...                                        ...                           ...
# 1457927                    定期入れ　カード入れ　小銭入れ　ピンク            レディース>小物>名刺入れ/定期入れ
# 1457928                             LOEWE マフラー            レディース>小物>マフラー/ショール
# 1457929                             ダーリッチ ストール            レディース>小物>ストール/スヌード
# 1457930  粘土道具 粘土ヘラ かきべら 6本セット クレイクラフト 陶芸 工芸 彫像        おもちゃ・ホビー・グッズ>アート用品>その他
# 1457931                           ジュース入れシャンデリア  自動車・オートバイ>自動車アクセサリー>車内アクセサリー
#
# [1457932 rows x 2 columns]

# %%
over1000_data["category"]
# Out:
# 0             おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ
# 1               おもちゃ・ホビー・グッズ>タレントグッズ>アイドル
# 2      おもちゃ・ホビー・グッズ>トレーディングカード>ポケモンカードゲーム
# 3                   本・音楽・ゲーム>CD>K-POP/アジア
# 4             おもちゃ・ホビー・グッズ>トレーディングカード>遊戯王
#                       ...
# 307             おもちゃ・ホビー・グッズ>おもちゃ>ホビーラジコン
# 308                     レディース>トップス>ベスト/ジレ
# 309        おもちゃ・ホビー・グッズ>コミック/アニメグッズ>ストラップ
# 310                チケット>優待券/割引券>レストラン/食事券
# 311                    ベビー・キッズ>行事/記念品>その他
# Name: category, Length: 312, dtype: object

# %%
len(df)
# Out:
# 1457932

# %%
data = df.merge(over1000_data)

# %%
data.category.value_counts()
# Out:
# category
# おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ           113754
# おもちゃ・ホビー・グッズ>タレントグッズ>アイドル              50977
# おもちゃ・ホビー・グッズ>トレーディングカード>ポケモンカードゲーム     24256
# 本・音楽・ゲーム>CD>K-POP/アジア                  21494
# おもちゃ・ホビー・グッズ>トレーディングカード>遊戯王            20234
#                                        ...
# おもちゃ・ホビー・グッズ>おもちゃ>ホビーラジコン               1017
# おもちゃ・ホビー・グッズ>コミック/アニメグッズ>ストラップ          1015
# レディース>トップス>ベスト/ジレ                       1015
# チケット>優待券/割引券>レストラン/食事券                  1005
# ベビー・キッズ>行事/記念品>その他                      1001
# Name: count, Length: 312, dtype: int64

# %%
data.nunique()
# Out:
# title       1218297
# category        312
# count           294
# dtype: int64

# %% [markdown]
# # テキストの前処理を行う

# %%
data.title
# Out:
# 0                                  カナヘイ ノートセット
# 1             DX ワンダーライドブック 2種 セット 仮面ライダー セイバー
# 2          田中くんはいつもけだるげまとめ売り クリアファイル アクキー 缶バッジ
# 3                       ディズニーワールドのクロックスのアクセサリー
# 4                                僕のヒーローアカデミア　轟
#                           ...
# 1218292                 未使用　ドモホルンリンクル 無料お試しセット
# 1218293                   くうちゃん様専用★美品★トリバーチ★財布
# 1218294                             LOEWE マフラー
# 1218295                             ダーリッチ ストール
# 1218296                           ジュース入れシャンデリア
# Name: title, Length: 1218297, dtype: object

# %%
emojis = "".join(emoji.EMOJI_DATA.keys())

# %%
emojis
# Out:
# '🥇🥈🥉🆎🏧🅰️🅰🇦🇫🇦🇱🇩🇿🇦🇸🇦🇩🇦🇴🇦🇮🇦🇶🇦🇬♒🇦🇷♈🇦🇲🇦🇼🇦🇨🇦🇺🇦🇹🇦🇿🔙🅱️🅱🇧🇸🇧🇭🇧🇩🇧🇧🇧🇾🇧🇪🇧🇿🇧🇯🇧🇲🇧🇹🇧🇴🇧🇦🇧🇼🇧🇻🇧🇷🇮🇴🇻🇬🇧🇳🇧🇬🇧🇫🇧🇮🆑🆒🇰🇭🇨🇲🇨🇦🇮🇨♋🇨🇻♑🇧🇶🇰🇾🇨🇫🇪🇦🇹🇩🇨🇱🇨🇳🇨🇽🎄🇨🇵🇨🇨🇨🇴🇰🇲🇨🇬🇨🇩🇨🇰🇨🇷🇭🇷🇨🇺🇨🇼🇨🇾🇨🇿🇨🇮🇩🇰🇩🇬🇩🇯🇩🇲🇩🇴🔚🇪🇨🇪🇬🇸🇻🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🇬🇶🇪🇷🇪🇪🇸🇿🇪🇹🇪🇺🆓🇫🇰🇫🇴🇫🇯🇫🇮🇫🇷🇬🇫🇵🇫🇹🇫🇬🇦🇬🇲♊🇬🇪🇩🇪🇬🇭🇬🇮🇬🇷🇬🇱🇬🇩🇬🇵🇬🇺🇬🇹🇬🇬🇬🇳🇬🇼🇬🇾🇭🇹🇭🇲🇭🇳🇭🇰🇭🇺🆔🇮🇸🇮🇳🇮🇩🇮🇷🇮🇶🇮🇪🇮🇲🇮🇱🇮🇹🇯🇲🇯🇵🉑🈸🉐🏯㊗️㊗🈹🎎🈚🈁🈷️🈷🈵🈶🈺🈴🏣🈲🈯㊙️㊙🈂️🈂🔰🈳🇯🇪🇯🇴🇰🇿🇰🇪🇰🇮🇽🇰🇰🇼🇰🇬🇱🇦🇱🇻🇱🇧♌🇱🇸🇱🇷♎🇱🇾🇱🇮🇱🇹🇱🇺🇲🇴🇲🇬🇲🇼🇲🇾🇲🇻🇲🇱🇲🇹🇲🇭🇲🇶🇲🇷🇲🇺🇾🇹🇲🇽🇫🇲🇲🇩🇲🇨🇲🇳🇲🇪🇲🇸🇲🇦🇲🇿🤶🤶🏿🤶🏻🤶🏾🤶🏼🤶🏽🇲🇲🆕🆖🇳🇦🇳🇷🇳🇵🇳🇱🇳🇨🇳🇿🇳🇮🇳🇪🇳🇬🇳🇺🇳🇫🇰🇵🇲🇰🇲🇵🇳🇴🆗👌👌🏿👌🏻👌🏾👌🏼👌🏽🔛🅾️🅾🇴🇲⛎🅿️🅿🇵🇰🇵🇼🇵🇸🇵🇦🇵🇬🇵🇾🇵🇪🇵🇭♓🇵🇳🇵🇱🇵🇹🇵🇷🇶🇦🇷🇴🇷🇺🇷🇼🇷🇪🔜🆘♐🇼🇸🇸🇲🎅🎅🏿🎅🏻🎅🏾🎅🏼🎅🏽🇸🇦♏🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f🇸🇳🇷🇸🇸🇨🇸🇱🇸🇬🇸🇽🇸🇰🇸🇮🇸🇧🇸🇴🇿🇦🇬🇸🇰🇷🇸🇸🇪🇸🇱🇰🇧🇱🇸🇭🇰🇳🇱🇨🇲🇫🇵🇲🇻🇨🗽🇸🇩🇸🇷🇸🇯🇸🇪🇨🇭🇸🇾🇸🇹🦖🔝🇹🇼🇹🇯🇹🇿♉🇹🇭🇹🇱🇹🇬🇹🇰🗼🇹🇴🇹🇹🇹🇦🇹🇳🇹🇷🇹🇲🇹🇨🇹🇻🇺🇲🇻🇮🆙🇺🇬🇺🇦🇦🇪🇬🇧🇺🇳🇺🇸🇺🇾🇺🇿🆚🇻🇺🇻🇦🇻🇪🇻🇳♍🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f🇼🇫🇪🇭🇾🇪🇿🇲🇿🇼🧮🪗🩹🎟️🎟🚡✈️✈🛬🛫⏰⚗️⚗👽👾🚑🏈🏺🫀⚓💢😠👿😧🐜📶😰🚛🧑\u200d🎨🧑🏿\u200d🎨🧑🏻\u200d🎨🧑🏾\u200d🎨🧑🏼\u200d🎨🧑🏽\u200d🎨🎨😲🧑\u200d🚀🧑🏿\u200d🚀🧑🏻\u200d🚀🧑🏾\u200d🚀🧑🏼\u200d🚀🧑🏽\u200d🚀⚛️⚛🛺🚗🥑🪓👶👼👼🏿👼🏻👼🏾👼🏼👼🏽🍼🐤👶🏿👶🏻👶🏾👶🏼👶🏽🚼👇👇🏿👇🏻👇🏾👇🏼👇🏽👈👈🏿👈🏻👈🏾
# ...

# %%
 string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
puncs = string.punctuation + "❗️♦️▼★①②③④⑤⑥⑦⑧⑨⓾●☆□【】『』「」★"

# %%
puncs
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~❗️♦️▼★①②③④⑤⑥⑦⑧⑨⓾●☆□【】『』「」★'

# %%
rm_signs = emojis + puncs

# %%
def han2zen(txt):
    return unicodedata.normalize('NFKC', txt)

def remove_signs(txt):
    rm_signs = list(emojis + puncs)
    for s in rm_signs:
        txt = txt.replace(s, "")
    return txt

def clean_txt(txt):
    txt = han2zen(txt)
    txt = remove_signs(txt)
    txt_list = txt.upper().split()
    txt_list = [x for x in txt_list if len(x) > 1 and re.search(r"[ぁ-んァ-ン一-龥a-zA-Z]", x)]
    return list(Counter(txt_list))

# %%
t = " ".join(["ｎikE","nike","shoes🥇","2000"])
print(t)
t = clean_txt(t)
print(t)
# Out:
# ｎikE nike shoes🥇 2000
# ['NIKE', 'SHOES']

# %%
print(type(data.title))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data.tail(30).title.apply(clean_txt)
# Out:
# 1218267          [サバゲー, 引退品, 電動エアガン, ショップカスタム品, TITAN]
# 1218268        [AQUOS, SENSE, PLUS, AU, SHV, SHRMフィルム]
# 1218269                    [送料込みXPERIA, SOLSOVガラスフィルム]
# 1218270                               [コーチ, COACH, 紙袋]
# 1218271                              [チェーンネックレス, ゴールド]
# 1218272                                      [ネックレス中古]
# 1218273                                      [ペンダント中古]
# 1218274           [大人気, ネックレス, レディース, ハート, ゴールド, かわいい]
# 1218275                      [フィリップオーディベールの連ハートブレスレット]
# 1218276                                  [温度で色が変わるリング]
# 1218277                     [マジカパーティ, アクロバッタ, SR, 未削り]
# 1218278               [大人気, フープピアス, レディース, ホワイト, シンプル]
# 1218279         [大人気ツイスト, ピアス, レディース, シルバー, フープ, シンプル]
# 1218280         [大人気, スタッドピアス, レディース, CZダイヤ, 高級, ゴールド]
# 1218281               [大人気, フープピアス, レディース, ブラック, シンプル]
# 1218282              [大人気, スタッドピアス, レディース, シルバー, シンプル]
# 1218283                 [フープピアス, KGP, ゴールド, ツイスト, ギフト]
# ...

# %%
data.tail(30).title
# Out:
# 1218267             サバゲー　引退品　電動エアガン　ショップカスタム品　TITAN
# 1218268    AQUOS sense3 Plus au SHV46 / SH-RM11フィルム
# 1218269            送料込みxperia 1 so-03L/sov40ガラスフィルム
# 1218270                                コーチ　coach 紙袋
# 1218271                              チェーンネックレス　ゴールド
# 1218272                               J71   ネックレス中古
# 1218273                               J52   ペンダント中古
# 1218274     A112 大人気！ ネックレス レディース k18 ハート ゴールド かわいい
# 1218275                    フィリップオーディベールの2連ハートブレスレット
# 1218276                           21.5号 温度で色が変わるリング
# 1218277                       マジカパーティ アクロバッタ SR 未削り
# 1218278         A98 大人気！ フープピアス レディース k18 ホワイト シンプル
# 1218279    A2 大人気！ツイスト ピアス レディース  k18 シルバー フープ シンプル
# 1218280        A84 大人気！ スタッドピアス レディース CZダイヤ　高級　ゴールド
# 1218281        A102 大人気！ フープピアス レディース k18 ブラック シンプル
# 1218282        A73 大人気！ スタッドピアス レディース k18 シルバー シンプル
# 1218283              A2  フープピアス　K18GP　ゴールド　ツイスト　ギフト
# 1218284                             Aqours×ドンキ アクキー
# ...

# %%
type(data.tail().title)
# Out:
# pandas.core.series.Series

# %%
data.tail().title.apply(clean_txt)
# Out:
# 1218292    [未使用, ドモホルンリンクル, 無料お試しセット]
# 1218293           [くうちゃん様専用美品トリバーチ財布]
# 1218294                 [LOEWE, マフラー]
# 1218295                 [ダーリッチ, ストール]
# 1218296                [ジュース入れシャンデリア]
# Name: title, dtype: object

# %%
data.tail().title
# Out:
# 1218292    未使用　ドモホルンリンクル 無料お試しセット
# 1218293      くうちゃん様専用★美品★トリバーチ★財布
# 1218294                LOEWE マフラー
# 1218295                ダーリッチ ストール
# 1218296              ジュース入れシャンデリア
# Name: title, dtype: object

# %%
tests = "emoji?"
tests = tests.replace("?", "")
print(tests)
# Out:
# emoji

# %%
data1 = {'A': [1, 2, 3], 'B': ['a', 'b', 'c']}
df = pd.DataFrame(data1)
df
# Out:
#    A  B
# 0  1  a
# 1  2  b
# 2  3  c

# %% [markdown]
# # テキストを数値に置き換える

# %%
# sklearn
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

# %%
category2idx = {c: idx for idx, c in enumerate(data.category.unique())}
idx2category = {idx: c for idx, c in enumerate(data.category.unique())}

# %%
data.category.apply(lambda x : category2idx[x])
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 1218292    11
# 1218293    13
# 1218294    22
# 1218295    23
# 1218296    24
# Name: category, Length: 1218297, dtype: int64

# %%
X = data.title
y = data.category.apply(lambda x : category2idx[x])

# %% [markdown]
# # データを学習させる

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
len(X)
# Out:
# 1218297

# %%
len(X_train)
# Out:
# 816258

# %%
len(X_test)
# Out:
# 402039

# %%
X_test
# Out:
# 1214612     【iPhoneケース】iPhone13北欧　花柄　ポップソケッツ付
# 236357                消防設備士試験　6類　筆記・実技　まとめて攻略
# 654419                うちの執事が言うことには パンフレット 永瀬廉
# 710573             遊戯王 ハーピィの羽根帚 ３枚セット　シク　ゴールド
# 652326                      「モアザンワーズ 1・2」 絵津鼓
#                           ...
# 1041174     うり坊様専用 fog linen work リネンウールワンピース
# 354108                          ピンクラインストーンピアス
# 987772     シンゾーン　THE SHINZONE GREENWICH JEANS
# 44249               最終値下〆GYDAカウチン完売品 定価¥21589
# 43365                        Avail フルジップニット L
# Name: title, Length: 402039, dtype: object

# %%
pipeline = Pipeline([
   ("bow", CountVectorizer()),
   ("tfidf", TfidfTransformer()),
   ("classifier", MultinomialNB())
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('classifier', MultinomialNB())])

# %%
pred = pipeline.predict(["【iPhoneケース】iPhone13北欧　花柄　ポップソケッツ付"])

# %%
pred
# Out:
# array([252])

# %%
y_test
# Out:
# 1214612    252
# 236357     125
# 654419     266
# 710573     154
# 652326     187
#           ...
# 1041174    229
# 354108     306
# 987772     106
# 44249      189
# 43365      140
# Name: category, Length: 402039, dtype: int64

# %%
print(classification_report(y_test, pred))
# Out:
# /Users/aipon/opt/anaconda3/envs/data_science/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.14      0.98      0.25     37598
#            1       1.00      0.02      0.05       402
#            2       1.00      0.01      0.03       479
#            3       0.72      0.12      0.21       725
#            4       1.00      0.04      0.07       339
#            5       0.90      0.02      0.04       468
#            6       0.89      0.03      0.06       506
#            7       1.00      0.02      0.05       449
#            8       1.00      0.00      0.01      1213
#            9       0.68      0.35      0.46       734
# ...

# %%
idx2category[147]
# Out:
# 'メンズ>アクセサリー>ブレスレット'

# %% [markdown]
# # 学習済みモデルを保存する

# %%
target = ["2022年度版 みんなが欲しかった! 賃貸不動産経営管理士の教科書"]
target
prediction = pipeline.predict(target)

# %%
prediction[0]
# Out:
# 217

# %%
type(target)
# Out:
# list

# %%
import pickle

# %%
with open("rdmf.pickle", mode="wb") as f:
    pickle.dump(pipeline, f)

# %%
ls
# Out:
# data_science.ipynb  rdmf.pickle         sample.csv

# %%
with open("rdmf.pickle", mode="rb") as ff:
    model = pickle.load(ff)

# %%
model.predict(target)
# Out:
# array([217])

# %%
pd.DataFrame([
   {"k":k, "v":v}
    for k, v in idx2category.items()
]).to_csv("idx2category.csv", index=False)

# %%
{row.k: row.v for idx, row in pd.read_csv("idx2category.csv").iterrows()}
# Out:
# {0: 'おもちゃ・ホビー・グッズ>おもちゃ>キャラクターグッズ',
#  1: 'レディース>アクセサリー>ブローチ/コサージュ',
#  2: 'その他>アンティーク/コレクション>雑貨',
#  3: 'おもちゃ・ホビー・グッズ>おもちゃ>プラモデル',
#  4: 'おもちゃ・ホビー・グッズ>おもちゃ>ホビーラジコン',
#  5: 'ベビー・キッズ>子ども用ファッション小物>帽子',
#  6: 'おもちゃ・ホビー・グッズ>おもちゃ>鉄道模型',
#  7: 'レディース>ヘアアクセサリー>ヘアバンド/カチューシャ',
#  8: 'おもちゃ・ホビー・グッズ>おもちゃ>その他',
#  9: 'レディース>ヘアアクセサリー>ヘアピン',
#  10: 'レディース>ヘアアクセサリー>その他',
#  11: 'コスメ・香水・美容>スキンケア/基礎化粧品>化粧水/ローション',
#  12: 'レディース>小物>長財布',
#  13: 'レディース>小物>折り財布',
#  14: 'コスメ・香水・美容>スキンケア/基礎化粧品>美容液',
#  15: 'コスメ・香水・美容>スキンケア/基礎化粧品>クレンジング/メイク落とし',
#  16: 'コスメ・香水・美容>スキンケア/基礎化粧品>洗顔料',
#  17: 'コスメ・香水・美容>スキンケア/基礎化粧品>パック/フェイスマスク',
#  18: 'レディース>小物>手袋/アームカバー',
#  19: 'コスメ・香水・美容>スキンケア/基礎化粧品>フェイスクリーム',
#  20: 'レディース>小物>ハンカチ',
#  21: 'コスメ・香水・美容>スキンケア/基礎化粧品>トライアルセット/サンプル',
#  22: 'レディース>小物>マフラー/ショール',
#  23: 'レディース>小物>ストール/スヌード',
#  24: '自動車・オートバイ>自動車アクセサリー>車内アクセサリー',
#  25: 'レディース>小物>その他',
#  26: 'おもちゃ・ホビー・グッズ>トレーディングカード>マジック：ザ・ギャザリング',
#  27: 'レディース>時計>腕時計(アナログ)',
#  28: 'おもちゃ・ホビー・グッズ>トレーディングカード>ポケモンカードゲーム',
# ...
